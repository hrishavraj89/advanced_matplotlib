# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# COLORED SCATTERPLOTS

# %%
iris = pd.read_csv('iris.csv')
iris.sample(5)
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 135  136            7.7           3.0            6.1           2.3
# 7      8            5.0           3.4            1.5           0.2
# 136  137            6.3           3.4            5.6           2.4
# 45    46            4.8           3.0            1.4           0.3
# 98    99            5.1           2.5            3.0           1.1
#
#              Species
# 135   Iris-virginica
# 7        Iris-setosa
# 136   Iris-virginica
# 45       Iris-setosa
# 98   Iris-versicolor

# %%
#assign number to the recurrent column(here species)
iris['Species'] = iris['Species'].replace({'Iris-setosa' : 0, 'Iris-versicolor' : 1, 'Iris-virginica' : 2})
# Out:
# C:\Users\HRISHAV RAJ\AppData\Local\Temp\ipykernel_3708\133978312.py:2: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   iris['Species'] = iris['Species'].replace({'Iris-setosa' : 0, 'Iris-versicolor' : 1, 'Iris-virginica' : 2})

# %%
#first we have to assign recurrent values a number, the reassign that column in the actual dataset and the use the hidden parameter 'c' like this.
#we can change the color styles using 'cmaps' 
#colorbar helps use to understand the which color represent which values.
#alpha helps to control the opacity of the scatter points.
plt.scatter(iris['SepalLengthCm'], iris['PetalLengthCm'], c = iris['Species'], cmap = 'jet', alpha = 0.6)
plt.xlabel('Sepal Length')
plt.ylabel('Petal Length')
plt.colorbar()
plt.show()

# %%
#plot size / Figure size
plt.figure(figsize=(15,7))
plt.scatter(iris['SepalLengthCm'], iris['PetalLengthCm'], c = iris['Species'], cmap = 'jet', alpha = 0.6)
plt.xlabel('Sepal Length')
plt.ylabel('Petal Length')
plt.colorbar()
plt.show()

# %% [markdown]
# ANNOTATIONS

# %%
x = [1,2,3,4]
y = [5,6,7,8]
plt.scatter(x,y)
#annotation
plt.text(1,5,'Point 1')
plt.text(2,6,'Point 2')
plt.text(3,7,'Point 3')
plt.text(4,8,'Point 4', fontdict = {'size':12, 'color':'red'})
# Out:
# Text(4, 8, 'Point 4')

# %%
batters = pd.read_csv('batter.csv')
batters
# Out:
#              batter  runs        avg  strike_rate
# 0           V Kohli  6634  36.251366   125.977972
# 1          S Dhawan  6244  34.882682   122.840842
# 2         DA Warner  5883  41.429577   136.401577
# 3         RG Sharma  5881  30.314433   126.964594
# 4          SK Raina  5536  32.374269   132.535312
# ..              ...   ...        ...          ...
# 600         C Nanda     0   0.000000     0.000000
# 601      Akash Deep     0   0.000000     0.000000
# 602         S Ladda     0   0.000000     0.000000
# 603  V Pratap Singh     0   0.000000     0.000000
# 604    S Lamichhane     0   0.000000     0.000000
#
# [605 rows x 4 columns]

# %%
batters.shape
# Out:
# (605, 4)

# %%
#randomly sselecting 25 batsman from top 100
sample_df = batters.head(100).sample(25, random_state = 5)
sample_df
# Out:
#            batter  runs        avg  strike_rate
# 66      KH Pandya  1326  22.100000   132.203390
# 32       SE Marsh  2489  39.507937   130.109775
# 46      JP Duminy  2029  39.784314   120.773810
# 28       SA Yadav  2644  29.707865   134.009123
# 74      IK Pathan  1150  21.698113   116.751269
# 23     JC Buttler  2832  39.333333   144.859335
# 10      G Gambhir  4217  31.007353   119.665153
# 20    BB McCullum  2882  27.711538   126.848592
# 17     KA Pollard  3437  28.404959   140.457703
# 35        WP Saha  2427  25.281250   124.397745
# 97  ST Jayasuriya   768  27.428571   134.031414
# 37     MA Agarwal  2335  22.669903   129.506378
# 70       DJ Hooda  1237  20.278689   127.525773
# 40         N Rana  2181  27.961538   130.053667
# 60      SS Tiwary  1494  28.730769   115.724245
# 34      JH Kallis  2427  28.552941   105.936272
# 42  KS Williamson  2105  36.293103   123.315759
# 57       DJ Bravo  1560  22.608696   125.100241
# 12      AM Rahane  4074  30.863636   117.575758
# ...

# %%
plt.scatter(sample_df['avg'], sample_df['strike_rate'])

# %%
#annotations on a dataframe
#here we run a loop to plot all the annotations

plt.figure(figsize = (15,7))
plt.scatter(sample_df['avg'], sample_df['strike_rate'], s = sample_df['runs'])   #'s' is used to define the size of the points depending on how much runs scored
for i in range (sample_df.shape[0]):
    plt.text(sample_df['avg'].values[i], sample_df['strike_rate'].values[i], sample_df['batter'].values[i])
plt.xlabel('Average')
plt.ylabel('Strike Rate')
# Out:
# Text(0, 0.5, 'Strike Rate')

# %% [markdown]
# PLOTTING HORIZONTAL AND VERTICAL LINES

# %%
plt.figure(figsize = (15,7))
plt.scatter(sample_df['avg'], sample_df['strike_rate'], s = sample_df['runs'])   #'s' is used to define the size of the points depending on how much runs scored

plt.axhline(130, color = 'red')
plt.axhline(140, color = 'green')
plt.axvline(30, color = 'red')

for i in range (sample_df.shape[0]):
    plt.text(sample_df['avg'].values[i], sample_df['strike_rate'].values[i], sample_df['batter'].values[i])
plt.xlabel('Average')
plt.ylabel('Strike Rate')
# Out:
# Text(0, 0.5, 'Strike Rate')

# %% [markdown]
# SUBPLOTS

# %%
#normal approach
plt.figure(figsize=(15,7))
plt.scatter(batters['avg'], batters['strike_rate'], marker = '+', color = 'red')
plt.title('Average vs Strike Rate')
plt.xlabel('Average')
plt.ylabel('Strike Rate')
plt.show()

# %%
#another approach
fig, ax = plt.subplots(figsize=(15,7))
ax.scatter(batters['avg'], batters['strike_rate'], marker = '+', color = 'red')
ax.set_title('Average vs Strike Rate')
ax.set_xlabel('Average')
ax.set_ylabel('Strike Rate')
fig.show()
# Out:
# C:\Users\HRISHAV RAJ\AppData\Local\Temp\ipykernel_3708\2596684531.py:7: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()

# %%
#plotting subplots
fig ,ax = plt.subplots(nrows = 2, ncols = 1)

# %%
fig

# %%
#we can notice it creates an array for the axis
ax
# Out:
# array([<Axes: >, <Axes: >], dtype=object)

# %%
#nrows = no. of rows
#ncols = no. of colums\
# nrows*ncols = total number of graphs you wanna create
# 'sharex=True' help to share the label across all the graphs
fig ,ax = plt.subplots(nrows = 2, ncols = 1, sharex=True, figsize=(10,6))

ax[0].scatter(batters['avg'], batters['strike_rate'], color = 'red')
ax[0].set_title('Average vs Strike Rate')
ax[0].set_ylabel('Strike Rate')

ax[1].scatter(batters['avg'], batters['runs'])
ax[1].set_title('Average vs Runs')
ax[1].set_xlabel('Average')
ax[1].set_ylabel('Runs')
# Out:
# Text(0, 0.5, 'Runs')

# %%
#creating 4 graphs
fig ,ax = plt.subplots(nrows = 2, ncols = 2, figsize=(10,6))

# %%
fig

# %%
#it now created an 2-d array
ax
# Out:
# array([[<Axes: >, <Axes: >],
#        [<Axes: >, <Axes: >]], dtype=object)

# %%
fig ,ax = plt.subplots(nrows = 2, ncols = 2, figsize=(10,6))

#we have to give two parameters to ax because its an 2-d arrray.
ax[0,0].scatter(batters['avg'], batters['strike_rate'], color = 'red')
ax[0,1].scatter(batters['avg'], batters['runs'], color = 'red')
ax[1,0].hist(batters['avg'])
ax[1,1].hist(batters['runs'])

fig.show()
# Out:
# C:\Users\HRISHAV RAJ\AppData\Local\Temp\ipykernel_3708\626503233.py:9: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()

# %% [markdown]
# 3-D SCATTERPLOTS

# %%
batters
# Out:
#              batter  runs        avg  strike_rate
# 0           V Kohli  6634  36.251366   125.977972
# 1          S Dhawan  6244  34.882682   122.840842
# 2         DA Warner  5883  41.429577   136.401577
# 3         RG Sharma  5881  30.314433   126.964594
# 4          SK Raina  5536  32.374269   132.535312
# ..              ...   ...        ...          ...
# 600         C Nanda     0   0.000000     0.000000
# 601      Akash Deep     0   0.000000     0.000000
# 602         S Ladda     0   0.000000     0.000000
# 603  V Pratap Singh     0   0.000000     0.000000
# 604    S Lamichhane     0   0.000000     0.000000
#
# [605 rows x 4 columns]

# %%
fig = plt.figure(figsize=(15,10))
ax = plt.subplot(projection='3d')   #we have to pass this line while creating 3d scatterplots
ax.scatter3D(batters['runs'], batters['avg'], batters['strike_rate'])

ax.set_title('Runs vs Average vs Strike Rate')
ax.set_xlabel('Runs')
ax.set_ylabel('Average')
ax.set_zlabel('Strike Rate')
# Out:
# Text(0.5, 0, 'Strike Rate')

# %% [markdown]
# 3-D LINE PLOT

# %%
x = [10,14,8,12]
y = [5,23,20,18]
z = [15,17,19,11]
fig = plt.figure()
ax = plt.subplot(projection='3d')
ax.scatter3D(x,y,z)
ax.plot(x,y,z, color='red')

# %% [markdown]
# 3-D SURFACE PLOTS
# - used to determine the working of the model

# %%
x = np.linspace(-10,10,100)
y = np.linspace(-10,10,100)

# %%
x
# Out:
# array([-10.        ,  -9.7979798 ,  -9.5959596 ,  -9.39393939,
#         -9.19191919,  -8.98989899,  -8.78787879,  -8.58585859,
#         -8.38383838,  -8.18181818,  -7.97979798,  -7.77777778,
#         -7.57575758,  -7.37373737,  -7.17171717,  -6.96969697,
#         -6.76767677,  -6.56565657,  -6.36363636,  -6.16161616,
#         -5.95959596,  -5.75757576,  -5.55555556,  -5.35353535,
#         -5.15151515,  -4.94949495,  -4.74747475,  -4.54545455,
#         -4.34343434,  -4.14141414,  -3.93939394,  -3.73737374,
#         -3.53535354,  -3.33333333,  -3.13131313,  -2.92929293,
#         -2.72727273,  -2.52525253,  -2.32323232,  -2.12121212,
#         -1.91919192,  -1.71717172,  -1.51515152,  -1.31313131,
#         -1.11111111,  -0.90909091,  -0.70707071,  -0.50505051,
#         -0.3030303 ,  -0.1010101 ,   0.1010101 ,   0.3030303 ,
#          0.50505051,   0.70707071,   0.90909091,   1.11111111,
#          1.31313131,   1.51515152,   1.71717172,   1.91919192,
# ...

# %%
xx, yy = np.meshgrid(x,y)

# %%
xx.shape
yy.shape
# Out:
# (100, 100)

# %%
z = xx**2 + yy**2
z.shape
# Out:
# (100, 100)

# %%
fig = plt.figure(figsize=(12,8))
ax = plt.subplot(projection='3d')
p = ax.plot_surface(xx,yy,z, cmap='viridis')
fig.colorbar(p)   #this is how we use colorbar in these.

# %%
zz = np.sin(xx)+np.cos(yy)
fig = plt.figure(figsize=(12,8))
ax = plt.subplot(projection='3d')
p = ax.plot_surface(xx,yy,zz, cmap='viridis')
fig.colorbar(p)

# %% [markdown]
# CONTOUR PLOTS
# - used to represent a 3d graph into 2d graph

# %%
#first variation
fig = plt.figure(figsize=(12,8))
ax = plt.subplot()
p = ax.contour(xx,yy,z, cmap='viridis')
fig.colorbar(p)

# %%
#second variation
fig = plt.figure(figsize=(12,8))
ax = plt.subplot()
p = ax.contourf(xx,yy,z, cmap='viridis')
fig.colorbar(p)

# %%
fig = plt.figure(figsize=(12,8))
ax = plt.subplot()
p = ax.contour(xx,yy,zz, cmap='viridis')
fig.colorbar(p)

# %%
fig = plt.figure(figsize=(12,8))
ax = plt.subplot()
p = ax.contourf(xx,yy,zz, cmap='viridis')
fig.colorbar(p)

# %% [markdown]
# HEATMAP

# %%
delivery = pd.read_csv('IPL_Ball_by_Ball_2008_2022.csv')
delivery.head()
# Out:
#         ID  innings  overs  ballnumber       batter          bowler  \
# 0  1312200        1      0           1  YBK Jaiswal  Mohammed Shami
# 1  1312200        1      0           2  YBK Jaiswal  Mohammed Shami
# 2  1312200        1      0           3   JC Buttler  Mohammed Shami
# 3  1312200        1      0           4  YBK Jaiswal  Mohammed Shami
# 4  1312200        1      0           5  YBK Jaiswal  Mohammed Shami
#
#    non-striker extra_type  batsman_run  extras_run  total_run  non_boundary  \
# 0   JC Buttler        NaN            0           0          0             0
# 1   JC Buttler    legbyes            0           1          1             0
# 2  YBK Jaiswal        NaN            1           0          1             0
# 3   JC Buttler        NaN            0           0          0             0
# 4   JC Buttler        NaN            0           0          0             0
#
#    isWicketDelivery player_out kind fielders_involved       BattingTeam
# ...

# %%
temp_df = delivery[(delivery['ballnumber'].isin([1, 2, 3, 4, 5, 6])) & (delivery['batsman_run'] == 6)]
temp_df
# Out:
#              ID  innings  overs  ballnumber       batter             bowler  \
# 16      1312200        1      2           5  YBK Jaiswal     Mohammed Shami
# 22      1312200        1      3           5  YBK Jaiswal         Yash Dayal
# 103     1312200        1     17           2     TA Boult      R Sai Kishore
# 107     1312200        1     17           6     OC McCoy      R Sai Kishore
# 142     1312200        2      3           5      MS Wade  M Prasidh Krishna
# ...         ...      ...    ...         ...          ...                ...
# 225848   335982        1     19           2  BB McCullum            P Kumar
# 225852   335982        1     19           6  BB McCullum            P Kumar
# 225882   335982        2      4           4    JH Kallis         AB Agarkar
# 225932   335982        2     12           1      P Kumar          LR Shukla
# 225944   335982        2     13           6      P Kumar         SC Ganguly
#
# ...

# %%
grid = temp_df.pivot_table(index='overs', columns='ballnumber', values='batsman_run', aggfunc='count')
grid
# Out:
# ballnumber    1    2    3    4    5    6
# overs
# 0             9   17   31   39   33   27
# 1            31   40   49   56   58   54
# 2            75   62   70   72   58   76
# 3            60   74   74  103   74   71
# 4            71   76  112   80   81   72
# 5            77  102   63   86   78   80
# 6            34   56   49   59   64   38
# 7            59   62   73   70   69   56
# 8            86   83   79   81   73   52
# 9            54   62   86   61   74   67
# 10           82   92   83   69   72   70
# 11           91   72   87   79   87   70
# 12           87  109   79  100  100   84
# 13          101  101   99   97   90   88
# 14           90  124  103  100   86  106
# 15          102  120  129  121  113   96
# 16          107  115  111  100  120  101
# 17          126  142  137  151  117  129
# 18          118  114  151  132  138  128
# 19          136  120  151  151  116  148

# %%
plt.figure(figsize=(20,10))
plt.imshow(grid)
plt.colorbar()
